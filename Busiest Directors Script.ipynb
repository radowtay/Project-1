# %%
#import libraries

import pandas as pd

# %%
#reference new csv
file="clean_data.csv"
df=pd.read_csv(file)

df=df.drop(columns="Unnamed: 0")

# %%
df.head()
# Out:
#                                        Title           Director  \
# 0                                    Avatar       James Cameron
# 1  Pirates of the Caribbean: At World's End      Gore Verbinski
# 2                                   Spectre          Sam Mendes
# 3                     The Dark Knight Rises   Christopher Nolan
# 4                               John Carter      Andrew Stanton
#
#    Movie Length (s)                            Genre Headlining Actor  \
# 0             178.0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1             169.0         Action|Adventure|Fantasy      Johnny Depp
# 2             148.0        Action|Adventure|Thriller  Christoph Waltz
# 3             164.0                  Action|Thriller        Tom Hardy
# 4             132.0          Action|Adventure|Sci-Fi     Daryl Sabara
#
#          Gross                                           Keywords Language  \
# 0  760505847.0             avatar|future|marine|native|paraplegic  English
# 1  309404152.0  goddess|marriage ceremony|marriage proposal|pi...  English
# 2  200074175.0                bomb|espionage|sequel|spy|terrorist  English
# 3  448130642.0  deception|imprisonment|lawlessness|police offi...  English
# 4   73058679.0  alien|american civil war|male nipple|mars|prin...  English
#
#   Country Rating       Budget  Release Year  IMDB Score  \
# 0     USA  PG-13  237000000.0        2009.0         7.9
# 1     USA  PG-13  300000000.0        2007.0         7.1
# 2      UK  PG-13  245000000.0        2015.0         6.8
# 3     USA  PG-13  250000000.0        2012.0         8.5
# 4     USA  PG-13  263700000.0        2012.0         6.6
#
#    Director Facebook Likes  Headlining Actor Facebook Likes  \
# 0                      0.0                           1000.0
# 1                    563.0                          40000.0
# 2                      0.0                          11000.0
# 3                  22000.0                          27000.0
# 4                    475.0                            640.0
#
#    Movie Facebook Likes  Cast Facebook Likes
# 0                 33000                 4834
# 1                     0                48350
# 2                 85000                11700
# 3                164000               106759
# 4                 24000                 1873

# %%
#play

fresh_df=df[["Director", "Title", "Movie Length (s)", "Release Year"]]
fresh_df.head()
# Out:
#             Director                                      Title  \
# 0      James Cameron                                    Avatar
# 1     Gore Verbinski  Pirates of the Caribbean: At World's End
# 2         Sam Mendes                                   Spectre
# 3  Christopher Nolan                     The Dark Knight Rises
# 4     Andrew Stanton                               John Carter
#
#    Movie Length (s)  Release Year
# 0             178.0        2009.0
# 1             169.0        2007.0
# 2             148.0        2015.0
# 3             164.0        2012.0
# 4             132.0        2012.0

# %%
fresh_df.set_index("Director").sort_index().head(20)
# Out:
#                                                         Title  \
# Director
# Aaron Schneider                                      Get Low
# Aaron Seltzer                                     Date Movie
# Abel Ferrara                                     The Funeral
# Adam Goldberg                               I Love Your Work
# Adam Marcus             Jason Goes to Hell: The Final Friday
# Adam McKay                                     Step Brothers
# Adam McKay                                    The Other Guys
# Adam McKay             Anchorman: The Legend of Ron Burgundy
# Adam McKay                 Anchorman 2: The Legend Continues
# Adam McKay                                     The Big Short
# Adam McKay       Talladega Nights: The Ballad of Ricky Bobby
# Adam Rapp                                     Winter Passing
# Adam Rifkin                                Detroit Rock City
# Adam Shankman                                Bedtime Stories
# Adam Shankman                            The Wedding Planner
# Adam Shankman                        Bringing Down the House
# Adam Shankman                                      Hairspray
# Adam Shankman                             A Walk to Remember
# Adam Shankman                         Cheaper by the Dozen 2
# Adam Shankman                                   The Pacifier
#
#                  Movie Length (s)  Release Year
# Director
# Aaron Schneider             100.0        2009.0
# Aaron Seltzer                85.0        2006.0
# Abel Ferrara                 99.0        1996.0
# Adam Goldberg               111.0        2003.0
# Adam Marcus                  91.0        1993.0
# Adam McKay                  106.0        2008.0
# Adam McKay                  116.0        2010.0
# Adam McKay                   98.0        2004.0
# Adam McKay                  143.0        2013.0
# Adam McKay                  130.0        2015.0
# Adam McKay                  122.0        2006.0
# Adam Rapp                    98.0        2005.0
# Adam Rifkin                  95.0        1999.0
# Adam Shankman                99.0        2008.0
# Adam Shankman               103.0        2001.0
# Adam Shankman               105.0        2003.0
# Adam Shankman               117.0        2007.0
# Adam Shankman               101.0        2002.0
# Adam Shankman                94.0        2005.0
# Adam Shankman                95.0        2005.0

# %%
# fresh_df.sort_values(by=["Release Year"])

#Find directors that appear the most
fresh_df.groupby("Director").count().head(20)
# Out:
#                             Title  Movie Length (s)  Release Year
# Director
# Aaron Schneider                 1                 1             1
# Aaron Seltzer                   1                 1             1
# Abel Ferrara                    1                 1             1
# Adam Goldberg                   1                 1             1
# Adam Marcus                     1                 1             1
# Adam McKay                      6                 6             6
# Adam Rapp                       1                 1             1
# Adam Rifkin                     1                 1             1
# Adam Shankman                   8                 8             8
# Adrian Lyne                     4                 4             4
# Adrienne Shelly                 1                 1             1
# Agnieszka Holland               1                 1             1
# Agnieszka Wojtowicz-Vosloo      1                 1             1
# Aki Kaurismäki                  1                 1             1
# Akira Kurosawa                  1                 1             1
# Akiva Goldsman                  1                 1             1
# Akiva Schaffer                  2                 2             2
# Alan Cohn                       1                 1             1
# Alan J. Pakula                  2                 2             2
# Alan Metter                     1                 1             1

# %%
fresh_df = fresh_df.loc[fresh_df.duplicated(subset='Director', keep=False), :]
fresh_df.groupby("Release Year").count().tail(20)
# Out:
#               Director  Title  Movie Length (s)
# Release Year
# 1997.0              84     84                84
# 1998.0              86     86                86
# 1999.0             114    114               114
# 2000.0             120    120               120
# 2001.0             134    134               134
# 2002.0             154    154               154
# 2003.0             114    114               114
# 2004.0             140    140               140
# 2005.0             139    139               139
# 2006.0             140    140               140
# 2007.0             114    114               114
# 2008.0             127    127               127
# 2009.0             134    134               134
# 2010.0             127    127               127
# 2011.0             135    135               135
# 2012.0             106    106               106
# 2013.0             127    127               127
# 2014.0             112    112               112
# 2015.0             100    100               100
# 2016.0              48     48                48

# %%
n=10
fresh_df["Director"].value_counts()[:n].index.tolist()
# Out:
# ['Steven Spielberg',
#  'Clint Eastwood',
#  'Woody Allen',
#  'Ridley Scott',
#  'Martin Scorsese',
#  'Tim Burton',
#  'Steven Soderbergh',
#  'Renny Harlin',
#  'Spike Lee',
#  'Robert Zemeckis']

# %%
top_10_df=fresh_df[(fresh_df["Director"] =='Steven Spielberg')|(fresh_df["Director"] =='Clint Eastwood')|
                   (fresh_df["Director"] =='Woody Allen')|(fresh_df["Director"] =='Ridley Scott')|
                   (fresh_df["Director"] =='Martin Scorsese')|(fresh_df["Director"] =='Tim Burton')|
                   (fresh_df["Director"] =='Steven Soderbergh')|(fresh_df["Director"] =='Renny Harlin')|
                   (fresh_df["Director"] =='Spike Lee')|(fresh_df["Director"] =='Robert Zemeckis')]

top_10_df
# Out:
#                Director                                              Title  \
# 21         Ridley Scott                                        Robin Hood
# 32           Tim Burton                               Alice in Wonderland
# 53     Steven Spielberg  Indiana Jones and the Kingdom of the Crystal S...
# 59      Robert Zemeckis                                 A Christmas Carol
# 68      Martin Scorsese                                              Hugo
# ...                 ...                                                ...
# 3470          Spike Lee                                    Get on the Bus
# 3500  Steven Soderbergh                                      Full Frontal
# 3581  Steven Soderbergh                          Sex, Lies, and Videotape
# 3774  Steven Soderbergh                                      Side Effects
# 3778          Spike Lee                               She's Gotta Have It
#
#       Movie Length (s)  Release Year
# 21               156.0        2010.0
# 32               108.0        2010.0
# 53               122.0        2008.0
# 59                96.0        2009.0
# 68               126.0        2011.0
# ...                ...           ...
# 3470             120.0        1996.0
# 3500             101.0        2002.0
# 3581             100.0        1989.0
# 3774             106.0        2013.0
# 3778              88.0        1986.0
#
# [171 rows x 4 columns]

# %%

