# %%
#import libraries

import pandas as pd
import matplotlib.pyplot as plt

# %%
#reference new csv
file="clean_data.csv"
df=pd.read_csv(file)

df=df.drop(columns="Unnamed: 0")

# %%
df.head()
# Out:
#                                        Title           Director  \
# 0                                    Avatar       James Cameron
# 1  Pirates of the Caribbean: At World's End      Gore Verbinski
# 2                                   Spectre          Sam Mendes
# 3                     The Dark Knight Rises   Christopher Nolan
# 4                               John Carter      Andrew Stanton
#
#    Movie Length (s)                            Genre Headlining Actor  \
# 0               178  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1               169         Action|Adventure|Fantasy      Johnny Depp
# 2               148        Action|Adventure|Thriller  Christoph Waltz
# 3               164                  Action|Thriller        Tom Hardy
# 4               132          Action|Adventure|Sci-Fi     Daryl Sabara
#
#        Gross                                           Keywords Language  \
# 0  760505847             avatar|future|marine|native|paraplegic  English
# 1  309404152  goddess|marriage ceremony|marriage proposal|pi...  English
# 2  200074175                bomb|espionage|sequel|spy|terrorist  English
# 3  448130642  deception|imprisonment|lawlessness|police offi...  English
# 4   73058679  alien|american civil war|male nipple|mars|prin...  English
#
#   Country Rating     Budget  Release Year  IMDB Score  \
# 0     USA  PG-13  237000000          2009         7.9
# 1     USA  PG-13  300000000          2007         7.1
# 2      UK  PG-13  245000000          2015         6.8
# 3     USA  PG-13  250000000          2012         8.5
# 4     USA  PG-13  263700000          2012         6.6
#
#    Director Facebook Likes  Headlining Actor Facebook Likes  \
# 0                        0                             1000
# 1                      563                            40000
# 2                        0                            11000
# 3                    22000                            27000
# 4                      475                              640
#
#    Movie Facebook Likes  Cast Facebook Likes
# 0                 33000                 4834
# 1                     0                48350
# 2                 85000                11700
# 3                164000               106759
# 4                 24000                 1873

# %%
hbg_df=df[["Title", "Genre", "Budget"]]
hbg_df["Budget"].astype(int)
hbg_df.head(20)
# Out:
#                                            Title  \
# 0                                        Avatar
# 1      Pirates of the Caribbean: At World's End
# 2                                       Spectre
# 3                         The Dark Knight Rises
# 4                                   John Carter
# 5                                  Spider-Man 3
# 6                                       Tangled
# 7                       Avengers: Age of Ultron
# 8        Harry Potter and the Half-Blood Prince
# 9            Batman v Superman: Dawn of Justice
# 10                             Superman Returns
# 11                            Quantum of Solace
# 12   Pirates of the Caribbean: Dead Man's Chest
# 13                              The Lone Ranger
# 14                                 Man of Steel
# 15     The Chronicles of Narnia: Prince Caspian
# 16                                 The Avengers
# 17  Pirates of the Caribbean: On Stranger Tides
# 18                               Men in Black 3
# 19    The Hobbit: The Battle of the Five Armies
#
#                                                 Genre     Budget
# 0                     Action|Adventure|Fantasy|Sci-Fi  237000000
# 1                            Action|Adventure|Fantasy  300000000
# 2                           Action|Adventure|Thriller  245000000
# 3                                     Action|Thriller  250000000
# 4                             Action|Adventure|Sci-Fi  263700000
# 5                            Action|Adventure|Romance  258000000
# 6   Adventure|Animation|Comedy|Family|Fantasy|Musi...  260000000
# 7                             Action|Adventure|Sci-Fi  250000000
# 8                    Adventure|Family|Fantasy|Mystery  250000000
# 9                             Action|Adventure|Sci-Fi  250000000
# 10                            Action|Adventure|Sci-Fi  209000000
# 11                                   Action|Adventure  200000000
# 12                           Action|Adventure|Fantasy  225000000
# 13                           Action|Adventure|Western  215000000
# 14                    Action|Adventure|Fantasy|Sci-Fi  225000000
# 15                    Action|Adventure|Family|Fantasy  225000000
# 16                            Action|Adventure|Sci-Fi  220000000
# 17                           Action|Adventure|Fantasy  250000000
# 18      Action|Adventure|Comedy|Family|Fantasy|Sci-Fi  225000000
# 19                                  Adventure|Fantasy  250000000

# %%
dupsearch=hbg_df
dupsearch
# Out:
#                                           Title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                         ...
# 3811                                    Primer
# 3812                                    Cavite
# 3813                               El Mariachi
# 3814                                 Newlyweds
# 3815                         My Date with Drew
#
#                                     Genre     Budget
# 0         Action|Adventure|Fantasy|Sci-Fi  237000000
# 1                Action|Adventure|Fantasy  300000000
# 2               Action|Adventure|Thriller  245000000
# 3                         Action|Thriller  250000000
# 4                 Action|Adventure|Sci-Fi  263700000
# ...                                   ...        ...
# 3811                Drama|Sci-Fi|Thriller       7000
# 3812                             Thriller       7000
# 3813  Action|Crime|Drama|Romance|Thriller       7000
# 3814                         Comedy|Drama       9000
# 3815                          Documentary       1100
#
# [3816 rows x 3 columns]

# %%
dupsearch_df=dupsearch.drop_duplicates(subset="Title", keep="first")

# %%
dupsearch_df["Budget"] = pd.to_numeric(dupsearch_df["Budget"])
dupsearch_df
# Out:
# C:\Users\Rachel\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                           Title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                         ...
# 3811                                    Primer
# 3812                                    Cavite
# 3813                               El Mariachi
# 3814                                 Newlyweds
# 3815                         My Date with Drew
#
#                                     Genre     Budget
# 0         Action|Adventure|Fantasy|Sci-Fi  237000000
# 1                Action|Adventure|Fantasy  300000000
# 2               Action|Adventure|Thriller  245000000
# 3                         Action|Thriller  250000000
# 4                 Action|Adventure|Sci-Fi  263700000
# ...                                   ...        ...
# 3811                Drama|Sci-Fi|Thriller       7000
# 3812                             Thriller       7000
# 3813  Action|Crime|Drama|Romance|Thriller       7000
# 3814                         Comedy|Drama       9000
# 3815                          Documentary       1100
#
# [3714 rows x 3 columns]

# %%
dupsearch_df["Budget"] = pd.to_numeric(dupsearch_df["Budget"])
# Out:
# C:\Users\Rachel\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                           Title  \
# 26                  Captain America: Civil War
# 7                      Avengers: Age of Ultron
# 9           Batman v Superman: Dawn of Justice
# 8       Harry Potter and the Half-Blood Prince
# 5                                 Spider-Man 3
# 6                                      Tangled
# 4                                  John Carter
# 1     Pirates of the Caribbean: At World's End
# 2489                                 Ong-bak 2
# 966    The Messenger: The Story of Joan of Arc
# 2925                  The Legend of Suriyothai
# 1265                                 Red Cliff
# 2756                    Kabhi Alvida Naa Kehna
# 3280                                     Tango
# 3609                             Godzilla 2000
# 2999                                     Akira
# 2155                                  Steamboy
# 2144                         Princess Mononoke
# 2708                                  Fateless
# 3285                            Lady Vengeance
#
#                                                   Genre      Budget
# 26                              Action|Adventure|Sci-Fi   250000000
# 7                               Action|Adventure|Sci-Fi   250000000
# 9                               Action|Adventure|Sci-Fi   250000000
# 8                      Adventure|Family|Fantasy|Mystery   250000000
# 5                              Action|Adventure|Romance   258000000
# 6     Adventure|Animation|Comedy|Family|Fantasy|Musi...   260000000
# 4                               Action|Adventure|Sci-Fi   263700000
# 1                              Action|Adventure|Fantasy   300000000
# 2489                                             Action   300000000
# 966               Adventure|Biography|Drama|History|War   390000000
# 2925                 Action|Adventure|Drama|History|War   400000000
# 1265                 Action|Adventure|Drama|History|War   553632000
# 2756                                              Drama   700000000
# 3280                                      Drama|Musical   700000000
# 3609             Action|Adventure|Drama|Sci-Fi|Thriller  1000000000
# 2999                            Action|Animation|Sci-Fi  1100000000
# 2155  Action|Adventure|Animation|Family|Sci-Fi|Thriller  2127519898
# 2144                        Adventure|Animation|Fantasy  2400000000
# 2708                                  Drama|Romance|War  2500000000
# 3285                                        Crime|Drama  4200000000

# %%
dupsearch_df=dupsearch_df.set_index("Genre")
dupsearch_df.sort_values(by='Budget').tail(20)
# Out:
#                                                                                         Title  \
# Genre
# Action|Adventure|Sci-Fi                                           Captain America: Civil War
# Action|Adventure|Sci-Fi                                              Avengers: Age of Ultron
# Action|Adventure|Sci-Fi                                   Batman v Superman: Dawn of Justice
# Adventure|Family|Fantasy|Mystery                      Harry Potter and the Half-Blood Prince
# Action|Adventure|Romance                                                        Spider-Man 3
# Adventure|Animation|Comedy|Family|Fantasy|Music...                                   Tangled
# Action|Adventure|Sci-Fi                                                          John Carter
# Action|Adventure|Fantasy                            Pirates of the Caribbean: At World's End
# Action                                                                             Ong-bak 2
# Adventure|Biography|Drama|History|War                The Messenger: The Story of Joan of Arc
# Action|Adventure|Drama|History|War                                  The Legend of Suriyothai
# Action|Adventure|Drama|History|War                                                 Red Cliff
# Drama                                                                 Kabhi Alvida Naa Kehna
# Drama|Musical                                                                          Tango
# Action|Adventure|Drama|Sci-Fi|Thriller                                         Godzilla 2000
# Action|Animation|Sci-Fi                                                                Akira
# Action|Adventure|Animation|Family|Sci-Fi|Thriller                                   Steamboy
# Adventure|Animation|Fantasy                                                Princess Mononoke
# Drama|Romance|War                                                                   Fateless
# Crime|Drama                                                                   Lady Vengeance
#
#                                                         Budget
# Genre
# Action|Adventure|Sci-Fi                              250000000
# Action|Adventure|Sci-Fi                              250000000
# Action|Adventure|Sci-Fi                              250000000
# Adventure|Family|Fantasy|Mystery                     250000000
# Action|Adventure|Romance                             258000000
# Adventure|Animation|Comedy|Family|Fantasy|Music...   260000000
# Action|Adventure|Sci-Fi                              263700000
# Action|Adventure|Fantasy                             300000000
# Action                                               300000000
# Adventure|Biography|Drama|History|War                390000000
# Action|Adventure|Drama|History|War                   400000000
# Action|Adventure|Drama|History|War                   553632000
# Drama                                                700000000
# Drama|Musical                                        700000000
# Action|Adventure|Drama|Sci-Fi|Thriller              1000000000
# Action|Animation|Sci-Fi                             1100000000
# Action|Adventure|Animation|Family|Sci-Fi|Thriller   2127519898
# Adventure|Animation|Fantasy                         2400000000
# Drama|Romance|War                                   2500000000
# Crime|Drama                                         4200000000

# %%
#I want to keep the first Genre listed before separator | to use as Genre for each movie
