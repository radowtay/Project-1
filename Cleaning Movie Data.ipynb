# %%
# Busiest Directors
# Line graph:genres with highest average budgets

import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
movie_data_csv = "Resources/movie_metadata.csv"
movie_df = pd.read_csv(movie_data_csv)
movie_df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 4                   131.0          NaN                      Documentary  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
# 2                994.0  English       UK           PG-13  245000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
# 4                  NaN      NaN      NaN             NaN          NaN
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
# 2      2015.0                  393.0        6.8          2.35
# 3      2012.0                23000.0        8.5          2.35
# 4         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %%
movie_df.drop(["aspect_ratio", "color", "num_user_for_reviews", 
               "num_critic_for_reviews", "actor_2_name", "actor_2_facebook_likes", 
               "actor_3_name", "actor_3_facebook_likes", "num_voted_users", "facenumber_in_poster",
              "movie_imdb_link"], axis=1, inplace=True)

# %%
list(movie_df.columns)
# Out:
# ['director_name',
#  'duration',
#  'director_facebook_likes',
#  'actor_1_facebook_likes',
#  'gross',
#  'genres',
#  'actor_1_name',
#  'movie_title',
#  'cast_total_facebook_likes',
#  'plot_keywords',
#  'language',
#  'country',
#  'content_rating',
#  'budget',
#  'title_year',
#  'imdb_score',
#  'movie_facebook_likes']

# %%
movie_df=movie_df.rename(columns={"movie_title":"Title", "director_name":"Director","duration":"Movie Length (s)", 
                          "genres":"Genre", "actor_1_name":"Headlining Actor", "gross":"Gross","plot_keywords":"Keywords",
                                 "language":"Language", "country":"Country", "content_rating":"Rating", "budget":"Budget",
                                 "title_year":"Release Year", "imdb_score":"IMDB Score", "director_facebook_likes":"Director Facebook Likes", 
                                  "actor_1_facebook_likes": "Headlining Actor Facebook Likes",
                                  "movie_facebook_likes":"Movie Facebook Likes", "cast_total_facebook_likes":"Cast Facebook Likes"})

# %%
movie_df[["Title","Director", "Movie Length (s)","Genre","Headlining Actor","Gross","Keywords","Language","Country","Rating",
         "Budget","Release Year","IMDB Score", "Director Facebook Likes","Headlining Actor Facebook Likes","Movie Facebook Likes", "Cast Facebook Likes"]]
# Out:
#                                                   Title           Director  \
# 0                                               Avatar       James Cameron
# 1             Pirates of the Caribbean: At World's End      Gore Verbinski
# 2                                              Spectre          Sam Mendes
# 3                                The Dark Knight Rises   Christopher Nolan
# 4     Star Wars: Episode VII - The Force Awakens    ...        Doug Walker
# ...                                                 ...                ...
# 5038                           Signed Sealed Delivered         Scott Smith
# 5039                         The Following                             NaN
# 5040                              A Plague So Pleasant    Benjamin Roberds
# 5041                                  Shanghai Calling         Daniel Hsia
# 5042                                 My Date with Drew            Jon Gunn
#
#       Movie Length (s)                            Genre Headlining Actor  \
# 0                178.0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                169.0         Action|Adventure|Fantasy      Johnny Depp
# 2                148.0        Action|Adventure|Thriller  Christoph Waltz
# 3                164.0                  Action|Thriller        Tom Hardy
# 4                  NaN                      Documentary      Doug Walker
# ...                ...                              ...              ...
# 5038              87.0                     Comedy|Drama      Eric Mabius
# 5039              43.0     Crime|Drama|Mystery|Thriller      Natalie Zea
# 5040              76.0            Drama|Horror|Thriller      Eva Boehnke
# 5041             100.0             Comedy|Drama|Romance        Alan Ruck
# 5042              90.0                      Documentary      John August
#
#             Gross                                           Keywords Language  \
# 0     760505847.0             avatar|future|marine|native|paraplegic  English
# 1     309404152.0  goddess|marriage ceremony|marriage proposal|pi...  English
# 2     200074175.0                bomb|espionage|sequel|spy|terrorist  English
# 3     448130642.0  deception|imprisonment|lawlessness|police offi...  English
# 4             NaN                                                NaN      NaN
# ...           ...                                                ...      ...
# 5038          NaN             fraud|postal worker|prison|theft|trial  English
# 5039          NaN       cult|fbi|hideout|prison escape|serial killer  English
# 5040          NaN                                                NaN  English
# 5041      10443.0                                                NaN  English
# 5042      85222.0  actress name in title|crush|date|four word tit...  English
#
#      Country Rating       Budget  Release Year  IMDB Score  \
# 0        USA  PG-13  237000000.0        2009.0         7.9
# 1        USA  PG-13  300000000.0        2007.0         7.1
# 2         UK  PG-13  245000000.0        2015.0         6.8
# 3        USA  PG-13  250000000.0        2012.0         8.5
# 4        NaN    NaN          NaN           NaN         7.1
# ...      ...    ...          ...           ...         ...
# 5038  Canada    NaN          NaN        2013.0         7.7
# 5039     USA  TV-14          NaN           NaN         7.5
# 5040     USA    NaN       1400.0        2013.0         6.3
# 5041     USA  PG-13          NaN        2012.0         6.3
# 5042     USA     PG       1100.0        2004.0         6.6
#
#       Director Facebook Likes  Headlining Actor Facebook Likes  \
# 0                         0.0                           1000.0
# 1                       563.0                          40000.0
# 2                         0.0                          11000.0
# 3                     22000.0                          27000.0
# 4                       131.0                            131.0
# ...                       ...                              ...
# 5038                      2.0                            637.0
# 5039                      NaN                            841.0
# 5040                      0.0                              0.0
# 5041                      0.0                            946.0
# 5042                     16.0                             86.0
#
#       Movie Facebook Likes  Cast Facebook Likes
# 0                    33000                 4834
# 1                        0                48350
# 2                    85000                11700
# 3                   164000               106759
# 4                        0                  143
# ...                    ...                  ...
# 5038                    84                 2283
# 5039                 32000                 1753
# 5040                    16                    0
# 5041                   660                 2386
# 5042                   456                  163
#
# [5043 rows x 17 columns]

# %%
clean_movie_df = movie_df.dropna()

# %%
clean_movie_df
# Out:
#                Director  Movie Length (s)  Director Facebook Likes  \
# 0         James Cameron             178.0                      0.0
# 1        Gore Verbinski             169.0                    563.0
# 2            Sam Mendes             148.0                      0.0
# 3     Christopher Nolan             164.0                  22000.0
# 5        Andrew Stanton             132.0                    475.0
# ...                 ...               ...                      ...
# 5033      Shane Carruth              77.0                    291.0
# 5034   Neill Dela Llana              80.0                      0.0
# 5035   Robert Rodriguez              81.0                      0.0
# 5037       Edward Burns              95.0                      0.0
# 5042           Jon Gunn              90.0                     16.0
#
#       Headlining Actor Facebook Likes        Gross  \
# 0                              1000.0  760505847.0
# 1                             40000.0  309404152.0
# 2                             11000.0  200074175.0
# 3                             27000.0  448130642.0
# 5                               640.0   73058679.0
# ...                               ...          ...
# 5033                            291.0     424760.0
# 5034                              0.0      70071.0
# 5035                            121.0    2040920.0
# 5037                            296.0       4584.0
# 5042                             86.0      85222.0
#
#                                     Genre Headlining Actor  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# 3                         Action|Thriller        Tom Hardy
# 5                 Action|Adventure|Sci-Fi     Daryl Sabara
# ...                                   ...              ...
# 5033                Drama|Sci-Fi|Thriller    Shane Carruth
# 5034                             Thriller      Ian Gamazon
# 5035  Action|Crime|Drama|Romance|Thriller  Carlos Gallardo
# 5037                         Comedy|Drama      Kerry Bishé
# 5042                          Documentary      John August
#
#                                           Title  Cast Facebook Likes  \
# 0                                       Avatar                  4834
# 1     Pirates of the Caribbean: At World's End                 48350
# 2                                      Spectre                 11700
# 3                        The Dark Knight Rises                106759
# 5                                  John Carter                  1873
# ...                                         ...                  ...
# 5033                                    Primer                   368
# 5034                                    Cavite                     0
# 5035                               El Mariachi                   147
# 5037                                 Newlyweds                   690
# 5042                         My Date with Drew                   163
#
#                                                Keywords Language      Country  \
# 0                avatar|future|marine|native|paraplegic  English          USA
# 1     goddess|marriage ceremony|marriage proposal|pi...  English          USA
# 2                   bomb|espionage|sequel|spy|terrorist  English           UK
# 3     deception|imprisonment|lawlessness|police offi...  English          USA
# 5     alien|american civil war|male nipple|mars|prin...  English          USA
# ...                                                 ...      ...          ...
# 5033  changing the future|independent film|invention...  English          USA
# 5034  jihad|mindanao|philippines|security guard|squa...  English  Philippines
# 5035                 assassin|death|guitar|gun|mariachi  Spanish          USA
# 5037                written and directed by cast member  English          USA
# 5042  actress name in title|crush|date|four word tit...  English          USA
#
#          Rating       Budget  Release Year  IMDB Score  Movie Facebook Likes
# 0         PG-13  237000000.0        2009.0         7.9                 33000
# 1         PG-13  300000000.0        2007.0         7.1                     0
# 2         PG-13  245000000.0        2015.0         6.8                 85000
# 3         PG-13  250000000.0        2012.0         8.5                164000
# 5         PG-13  263700000.0        2012.0         6.6                 24000
# ...         ...          ...           ...         ...                   ...
# 5033      PG-13       7000.0        2004.0         7.0                 19000
# 5034  Not Rated       7000.0        2005.0         6.3                    74
# 5035          R       7000.0        1992.0         6.9                     0
# 5037  Not Rated       9000.0        2011.0         6.4                   413
# 5042         PG       1100.0        2004.0         6.6                   456
#
# [3816 rows x 17 columns]
